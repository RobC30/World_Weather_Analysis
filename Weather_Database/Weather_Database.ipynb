# %%
# import dependencies

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c6a5c7b509fda8562fb78d6e53441ad

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kropotkin
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | calabozo
# Processing Record 6 of Set 1 | asau
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | foggia
# Processing Record 9 of Set 1 | sitrah
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | srednekolymsk
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | ahipara
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | kondoa
# Processing Record 19 of Set 1 | nylstroom
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | medicine hat
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | coihaique
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | the valley
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | niquelandia
# Processing Record 36 of Set 1 | chachoengsao
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 1 | mana
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | agirish
# Processing Record 41 of Set 1 | zambezi
# Processing Record 42 of Set 1 | san carlos
# Processing Record 43 of Set 1 | harper
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 1 | vostok
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 1 | alyangula
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | ellisras
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | blagoveshchensk
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | westport
# Processing Record 8 of Set 2 | shache
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | oktyabrskoye
# Processing Record 11 of Set 2 | panama city
# Processing Record 12 of Set 2 | bambanglipuro
# Processing Record 13 of Set 2 | ihosy
# Processing Record 14 of Set 2 | yulara
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | verkhoyansk
# Processing Record 17 of Set 2 | marrakesh
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-louis
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | burnie
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | pangnirtung
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | matiguas
# Processing Record 28 of Set 2 | chunhuhub
# Processing Record 29 of Set 2 | oxapampa
# Processing Record 30 of Set 2 | grindavik
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | betioky
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | hambantota
# Processing Record 41 of Set 2 | alamosa
# Processing Record 42 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 2 | asfi
# Processing Record 44 of Set 2 | ekhabi
# Processing Record 45 of Set 2 | clarence town
# Processing Record 46 of Set 2 | turkistan
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | batagay
# Processing Record 49 of Set 2 | lagoa
# Processing Record 50 of Set 2 | mayya
# Processing Record 1 of Set 3 | sigli
# Processing Record 2 of Set 3 | syracuse
# Processing Record 3 of Set 3 | broken hill
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | slavjanovo
# Processing Record 6 of Set 3 | najran
# Processing Record 7 of Set 3 | lubumbashi
# Processing Record 8 of Set 3 | barra do garcas
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | antalaha
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | le port
# Processing Record 13 of Set 3 | vega de alatorre
# Processing Record 14 of Set 3 | katherine
# Processing Record 15 of Set 3 | komsomolskiy
# Processing Record 16 of Set 3 | eldorado
# Processing Record 17 of Set 3 | polovinnoye
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | mataura
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | bombo
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | tazovskiy
# Processing Record 26 of Set 3 | amazar
# Processing Record 27 of Set 3 | maragogi
# Processing Record 28 of Set 3 | severo-yeniseyskiy
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | banepa
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | olinda
# Processing Record 33 of Set 3 | mogadishu
# Processing Record 34 of Set 3 | talcahuano
# Processing Record 35 of Set 3 | mar del plata
# Processing Record 36 of Set 3 | birsk
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | hornepayne
# Processing Record 41 of Set 3 | evensk
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | slave lake
# Processing Record 45 of Set 3 | luwuk
# Processing Record 46 of Set 3 | chitral
# Processing Record 47 of Set 3 | general roca
# Processing Record 48 of Set 3 | bima
# Processing Record 49 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | bud
# Processing Record 2 of Set 4 | laguna
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | cacule
# Processing Record 6 of Set 4 | peruibe
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 9 of Set 4 | nishihara
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | ust-koksa
# Processing Record 12 of Set 4 | kodinsk
# Processing Record 13 of Set 4 | kiruna
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | puerto quijarro
# Processing Record 17 of Set 4 | tha rua
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | flinders
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | cubuk
# Processing Record 23 of Set 4 | hobyo
# Processing Record 24 of Set 4 | quatre cocos
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | angra
# City not found. Skipping...
# Processing Record 27 of Set 4 | ponta delgada
# Processing Record 28 of Set 4 | lingao
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | toowoomba
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | mengcheng
# Processing Record 33 of Set 4 | tondano
# Processing Record 34 of Set 4 | san andres
# Processing Record 35 of Set 4 | niteroi
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | tutoia
# Processing Record 38 of Set 4 | rio grande
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | sur
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | chumikan
# Processing Record 44 of Set 4 | oktyabrskiy
# Processing Record 45 of Set 4 | necochea
# Processing Record 46 of Set 4 | camacha
# Processing Record 47 of Set 4 | binabalian
# Processing Record 48 of Set 4 | kamenka
# Processing Record 49 of Set 4 | cabedelo
# Processing Record 50 of Set 4 | ballina
# Processing Record 1 of Set 5 | dunedin
# Processing Record 2 of Set 5 | senanga
# Processing Record 3 of Set 5 | houma
# Processing Record 4 of Set 5 | vitimskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | havre
# Processing Record 6 of Set 5 | markova
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | bosaso
# Processing Record 9 of Set 5 | pevek
# Processing Record 10 of Set 5 | nueva concepcion
# Processing Record 11 of Set 5 | shimla
# Processing Record 12 of Set 5 | korla
# Processing Record 13 of Set 5 | launceston
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | gambela
# Processing Record 16 of Set 5 | bilibino
# Processing Record 17 of Set 5 | ternate
# Processing Record 18 of Set 5 | akureyri
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | chapais
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | sarkand
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | saint-joseph
# Processing Record 26 of Set 5 | excelsior springs
# Processing Record 27 of Set 5 | bizhbulyak
# Processing Record 28 of Set 5 | rawson
# Processing Record 29 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 5 | oda
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 5 | kuryk
# Processing Record 33 of Set 5 | zaozerne
# Processing Record 34 of Set 5 | san patricio
# Processing Record 35 of Set 5 | swan hill
# Processing Record 36 of Set 5 | vaovai
# City not found. Skipping...
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | nhulunbuy
# Processing Record 39 of Set 5 | airai
# Processing Record 40 of Set 5 | talara
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | casino
# Processing Record 43 of Set 5 | alekseyevka
# Processing Record 44 of Set 5 | los pozos
# Processing Record 45 of Set 5 | port blair
# Processing Record 46 of Set 5 | hare bay
# Processing Record 47 of Set 5 | srandakan
# Processing Record 48 of Set 5 | dikson
# Processing Record 49 of Set 5 | bere
# Processing Record 50 of Set 5 | vila franca do campo
# Processing Record 1 of Set 6 | mae hong son
# Processing Record 2 of Set 6 | fukue
# Processing Record 3 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 6 | walvis bay
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | killybegs
# Processing Record 7 of Set 6 | vizinga
# Processing Record 8 of Set 6 | carnarvon
# Processing Record 9 of Set 6 | saint-michel-des-saints
# Processing Record 10 of Set 6 | champerico
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | shelburne
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | san luis
# Processing Record 15 of Set 6 | boa vista
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | dawlatabad
# Processing Record 18 of Set 6 | truro
# Processing Record 19 of Set 6 | micheweni
# Processing Record 20 of Set 6 | cuamba
# Processing Record 21 of Set 6 | belaya gora
# Processing Record 22 of Set 6 | bay roberts
# Processing Record 23 of Set 6 | yumen
# Processing Record 24 of Set 6 | teya
# Processing Record 25 of Set 6 | aketi
# Processing Record 26 of Set 6 | ilulissat
# Processing Record 27 of Set 6 | sumbe
# Processing Record 28 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 29 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | marstal
# Processing Record 31 of Set 6 | russell
# Processing Record 32 of Set 6 | ravar
# Processing Record 33 of Set 6 | iqaluit
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | luanda
# Processing Record 36 of Set 6 | skovorodino
# Processing Record 37 of Set 6 | tlaxiaco
# City not found. Skipping...
# Processing Record 38 of Set 6 | stornoway
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | kananga
# Processing Record 41 of Set 6 | shakawe
# Processing Record 42 of Set 6 | talavera de la reina
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | mareeba
# Processing Record 45 of Set 6 | port said
# Processing Record 46 of Set 6 | la sarre
# Processing Record 47 of Set 6 | hithadhoo
# Processing Record 48 of Set 6 | altamira
# Processing Record 49 of Set 6 | kamina
# Processing Record 50 of Set 6 | mitu
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | silver city
# Processing Record 4 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 7 | dzhebariki-khaya
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | nikolayevsk-na-amure
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | fairbanks
# Processing Record 10 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | askino
# Processing Record 13 of Set 7 | parakai
# Processing Record 14 of Set 7 | pangody
# Processing Record 15 of Set 7 | cayenne
# Processing Record 16 of Set 7 | iracoubo
# Processing Record 17 of Set 7 | khandagayty
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | xai-xai
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | saldanha
# Processing Record 22 of Set 7 | fort-shevchenko
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | constitucion
# Processing Record 25 of Set 7 | aklavik
# Processing Record 26 of Set 7 | jumla
# Processing Record 27 of Set 7 | corinth
# Processing Record 28 of Set 7 | mahibadhoo
# Processing Record 29 of Set 7 | razole
# Processing Record 30 of Set 7 | kralendijk
# Processing Record 31 of Set 7 | gunnedah
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | hirara
# Processing Record 34 of Set 7 | guadalupe y calvo
# Processing Record 35 of Set 7 | loudi
# Processing Record 36 of Set 7 | hay river
# Processing Record 37 of Set 7 | meulaboh
# Processing Record 38 of Set 7 | mago
# Processing Record 39 of Set 7 | carballo
# Processing Record 40 of Set 7 | marzuq
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | madang
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | tuatapere
# Processing Record 45 of Set 7 | mawlaik
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | chuy
# Processing Record 48 of Set 7 | paragominas
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | codrington
# Processing Record 1 of Set 8 | degtyarsk
# Processing Record 2 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 8 | clyde river
# Processing Record 4 of Set 8 | namatanai
# Processing Record 5 of Set 8 | northam
# Processing Record 6 of Set 8 | anchorage
# Processing Record 7 of Set 8 | ingham
# Processing Record 8 of Set 8 | khasan
# Processing Record 9 of Set 8 | denpasar
# Processing Record 10 of Set 8 | strezhevoy
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | poum
# Processing Record 13 of Set 8 | yaan
# Processing Record 14 of Set 8 | pandan
# Processing Record 15 of Set 8 | whitefish
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | farafangana
# Processing Record 18 of Set 8 | saint anthony
# Processing Record 19 of Set 8 | ust-tsilma
# Processing Record 20 of Set 8 | toora-khem
# Processing Record 21 of Set 8 | ako
# Processing Record 22 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 23 of Set 8 | emba
# Processing Record 24 of Set 8 | sechura
# Processing Record 25 of Set 8 | wilmington
# Processing Record 26 of Set 8 | lipin bor
# Processing Record 27 of Set 8 | hammerfest
# Processing Record 28 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 8 | voh
# Processing Record 30 of Set 8 | makakilo city
# Processing Record 31 of Set 8 | cururupu
# Processing Record 32 of Set 8 | ferrol
# Processing Record 33 of Set 8 | george town
# Processing Record 34 of Set 8 | beringovskiy
# Processing Record 35 of Set 8 | kuytun
# Processing Record 36 of Set 8 | tongliao
# Processing Record 37 of Set 8 | alto araguaia
# Processing Record 38 of Set 8 | gat
# Processing Record 39 of Set 8 | key west
# Processing Record 40 of Set 8 | chifeng
# Processing Record 41 of Set 8 | snezhnogorsk
# Processing Record 42 of Set 8 | xacmaz
# Processing Record 43 of Set 8 | hecelchakan
# Processing Record 44 of Set 8 | takoradi
# Processing Record 45 of Set 8 | morro bay
# Processing Record 46 of Set 8 | birjand
# Processing Record 47 of Set 8 | krasnoselkup
# Processing Record 48 of Set 8 | guerrero negro
# Processing Record 49 of Set 8 | kibre mengist
# Processing Record 50 of Set 8 | palmer
# Processing Record 1 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 2 of Set 9 | pacific grove
# Processing Record 3 of Set 9 | peleduy
# Processing Record 4 of Set 9 | bandarbeyla
# Processing Record 5 of Set 9 | manado
# Processing Record 6 of Set 9 | kalmunai
# Processing Record 7 of Set 9 | hojai
# Processing Record 8 of Set 9 | cremona
# Processing Record 9 of Set 9 | haines junction
# Processing Record 10 of Set 9 | praya
# Processing Record 11 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 9 | marsh harbour
# Processing Record 13 of Set 9 | port hedland
# Processing Record 14 of Set 9 | zhigalovo
# Processing Record 15 of Set 9 | dahuk
# Processing Record 16 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 9 | port lincoln
# Processing Record 18 of Set 9 | lorengau
# Processing Record 19 of Set 9 | guaruja
# Processing Record 20 of Set 9 | shimoda
# Processing Record 21 of Set 9 | eyl
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | guayaramerin
# Processing Record 24 of Set 9 | boyolangu
# Processing Record 25 of Set 9 | mehamn
# Processing Record 26 of Set 9 | matara
# Processing Record 27 of Set 9 | sioux lookout
# Processing Record 28 of Set 9 | rabo de peixe
# Processing Record 29 of Set 9 | puerto escondido
# Processing Record 30 of Set 9 | raga
# Processing Record 31 of Set 9 | benguela
# Processing Record 32 of Set 9 | safaga
# Processing Record 33 of Set 9 | pochutla
# Processing Record 34 of Set 9 | namibe
# Processing Record 35 of Set 9 | boueni
# Processing Record 36 of Set 9 | mweka
# Processing Record 37 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | soldotna
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | goundam
# Processing Record 42 of Set 9 | buxton
# Processing Record 43 of Set 9 | khorixas
# Processing Record 44 of Set 9 | taoudenni
# Processing Record 45 of Set 9 | saint-pierre
# Processing Record 46 of Set 9 | san carlos de bariloche
# Processing Record 47 of Set 9 | sakaiminato
# Processing Record 48 of Set 9 | ganzhou
# Processing Record 49 of Set 9 | xining
# Processing Record 50 of Set 9 | petrovskaya
# Processing Record 1 of Set 10 | belmonte
# Processing Record 2 of Set 10 | anori
# Processing Record 3 of Set 10 | abu dhabi
# Processing Record 4 of Set 10 | partenit
# Processing Record 5 of Set 10 | pemba
# Processing Record 6 of Set 10 | borgarnes
# Processing Record 7 of Set 10 | ayan
# Processing Record 8 of Set 10 | padang
# Processing Record 9 of Set 10 | bardiyah
# Processing Record 10 of Set 10 | general pico
# Processing Record 11 of Set 10 | acarau
# Processing Record 12 of Set 10 | muravlenko
# Processing Record 13 of Set 10 | sisimiut
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | rypefjord
# Processing Record 16 of Set 10 | tibati
# Processing Record 17 of Set 10 | axim
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | havre-saint-pierre
# Processing Record 20 of Set 10 | hailar
# Processing Record 21 of Set 10 | kichmengskiy gorodok
# Processing Record 22 of Set 10 | ust-maya
# Processing Record 23 of Set 10 | guiratinga
# Processing Record 24 of Set 10 | mudbidri
# Processing Record 25 of Set 10 | nelson bay
# Processing Record 26 of Set 10 | cabo san lucas
# Processing Record 27 of Set 10 | figeac
# Processing Record 28 of Set 10 | porbandar
# Processing Record 29 of Set 10 | klyuchi
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | batemans bay
# Processing Record 32 of Set 10 | onguday
# Processing Record 33 of Set 10 | kerman
# Processing Record 34 of Set 10 | devonport
# Processing Record 35 of Set 10 | pisco
# Processing Record 36 of Set 10 | kavieng
# Processing Record 37 of Set 10 | mayo
# Processing Record 38 of Set 10 | vestmannaeyjar
# Processing Record 39 of Set 10 | hastings
# Processing Record 40 of Set 10 | roebourne
# Processing Record 41 of Set 10 | vaitape
# Processing Record 42 of Set 10 | kupang
# Processing Record 43 of Set 10 | ilo
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | santa ines
# Processing Record 46 of Set 10 | beyneu
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | havelock
# Processing Record 49 of Set 10 | svobodnyy
# Processing Record 50 of Set 10 | chengde
# Processing Record 1 of Set 11 | gurupi
# Processing Record 2 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 11 | banda aceh
# Processing Record 4 of Set 11 | yazd
# Processing Record 5 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 11 | menongue
# Processing Record 9 of Set 11 | agua dulce
# Processing Record 10 of Set 11 | baragua
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | muisne
# Processing Record 13 of Set 11 | kontagora
# Processing Record 14 of Set 11 | kinsale
# Processing Record 15 of Set 11 | zhigansk
# Processing Record 16 of Set 11 | hofn
# Processing Record 17 of Set 11 | erzin
# Processing Record 18 of Set 11 | manaure
# Processing Record 19 of Set 11 | las vegas
# Processing Record 20 of Set 11 | silopi
# Processing Record 21 of Set 11 | cervo
# Processing Record 22 of Set 11 | mahajanga
# Processing Record 23 of Set 11 | quesnel
# Processing Record 24 of Set 11 | moorhead
# Processing Record 25 of Set 11 | erenhot
# Processing Record 26 of Set 11 | inirida
# Processing Record 27 of Set 11 | ullapool
# Processing Record 28 of Set 11 | coxim
# Processing Record 29 of Set 11 | cimitarra
# Processing Record 30 of Set 11 | anshun
# Processing Record 31 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 11 | jimenez
# Processing Record 33 of Set 11 | smithers
# Processing Record 34 of Set 11 | churapcha
# Processing Record 35 of Set 11 | hommelvik
# Processing Record 36 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 11 | wuchi
# Processing Record 38 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 11 | kamisu
# Processing Record 40 of Set 11 | domoni
# Processing Record 41 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 11 | ucluelet
# Processing Record 43 of Set 11 | brigantine
# Processing Record 44 of Set 11 | tomislavgrad
# Processing Record 45 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 46 of Set 11 | stranraer
# Processing Record 47 of Set 11 | sobolevo
# Processing Record 48 of Set 11 | vestmanna
# Processing Record 49 of Set 11 | shimanovsk
# Processing Record 50 of Set 11 | mattawa
# Processing Record 1 of Set 12 | mombetsu
# Processing Record 2 of Set 12 | buala
# Processing Record 3 of Set 12 | vilcun
# Processing Record 4 of Set 12 | sapele
# Processing Record 5 of Set 12 | batagay-alyta
# Processing Record 6 of Set 12 | urumqi
# Processing Record 7 of Set 12 | vallenar
# Processing Record 8 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 12 | lapeer
# Processing Record 10 of Set 12 | sfantu gheorghe
# Processing Record 11 of Set 12 | jaslo
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | sapa
# Processing Record 14 of Set 12 | kemijarvi
# Processing Record 15 of Set 12 | kidal
# Processing Record 16 of Set 12 | bubaque
# Processing Record 17 of Set 12 | izumo
# Processing Record 18 of Set 12 | yandyki
# Processing Record 19 of Set 12 | phan thiet
# Processing Record 20 of Set 12 | malatya
# Processing Record 21 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 12 | kelso
# Processing Record 23 of Set 12 | jacareacanga
# Processing Record 24 of Set 12 | sinjar
# Processing Record 25 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | grayslake
# Processing Record 27 of Set 12 | onega
# Processing Record 28 of Set 12 | camacupa
# Processing Record 29 of Set 12 | la paz
# Processing Record 30 of Set 12 | port hawkesbury
# Processing Record 31 of Set 12 | husavik
# Processing Record 32 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 12 | ambilobe
# Processing Record 34 of Set 12 | charters towers
# Processing Record 35 of Set 12 | nalut
# Processing Record 36 of Set 12 | celle
# Processing Record 37 of Set 12 | amahai
# Processing Record 38 of Set 12 | balkanabat
# Processing Record 39 of Set 12 | bronkhorstspruit
# Processing Record 40 of Set 12 | margate
# Processing Record 41 of Set 12 | kenai
# Processing Record 42 of Set 12 | pouembout
# Processing Record 43 of Set 12 | at-bashi
# Processing Record 44 of Set 12 | manacapuru
# Processing Record 45 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | santiago del estero
# Processing Record 47 of Set 12 | nemuro
# Processing Record 48 of Set 12 | manokwari
# Processing Record 49 of Set 12 | half moon bay
# Processing Record 50 of Set 12 | galeana
# Processing Record 1 of Set 13 | kununurra
# Processing Record 2 of Set 13 | antofagasta
# Processing Record 3 of Set 13 | pa sang
# Processing Record 4 of Set 13 | beinamar
# Processing Record 5 of Set 13 | mecca
# Processing Record 6 of Set 13 | narrabri
# Processing Record 7 of Set 13 | hualmay
# Processing Record 8 of Set 13 | kharsawan
# Processing Record 9 of Set 13 | yerkoy
# Processing Record 10 of Set 13 | ilheus
# Processing Record 11 of Set 13 | port-cartier
# Processing Record 12 of Set 13 | puerto leguizamo
# Processing Record 13 of Set 13 | altay
# Processing Record 14 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 13 | sao jose da coroa grande
# Processing Record 16 of Set 13 | sitka
# Processing Record 17 of Set 13 | chernyshevskiy
# Processing Record 18 of Set 13 | baikunthpur
# Processing Record 19 of Set 13 | sawtell
# Processing Record 20 of Set 13 | beloha
# Processing Record 21 of Set 13 | novo aripuana
# Processing Record 22 of Set 13 | pitimbu
# Processing Record 23 of Set 13 | ati
# Processing Record 24 of Set 13 | patti
# Processing Record 25 of Set 13 | bolkhov
# Processing Record 26 of Set 13 | sao joao da barra
# Processing Record 27 of Set 13 | san policarpo
# Processing Record 28 of Set 13 | watertown
# Processing Record 29 of Set 13 | lodja
# Processing Record 30 of Set 13 | odda
# Processing Record 31 of Set 13 | kahului
# Processing Record 32 of Set 13 | langenau
# Processing Record 33 of Set 13 | sumenep
# Processing Record 34 of Set 13 | kanniyakumari
# Processing Record 35 of Set 13 | berlevag
# Processing Record 36 of Set 13 | kamaishi
# Processing Record 37 of Set 13 | uglovka
# Processing Record 38 of Set 13 | sandakan
# Processing Record 39 of Set 13 | goderich
# Processing Record 40 of Set 13 | ibague
# Processing Record 41 of Set 13 | san jose
# Processing Record 42 of Set 13 | andenes
# Processing Record 43 of Set 13 | noumea
# Processing Record 44 of Set 13 | shitanjing
# Processing Record 45 of Set 13 | payyannur
# Processing Record 46 of Set 13 | viedma
# Processing Record 47 of Set 13 | boguchany
# Processing Record 48 of Set 13 | samarai
# Processing Record 49 of Set 13 | glasgow
# Processing Record 50 of Set 13 | mocuba
# Processing Record 1 of Set 14 | kailua
# Processing Record 2 of Set 14 | athabasca
# Processing Record 3 of Set 14 | bela
# Processing Record 4 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 14 | kendari
# Processing Record 6 of Set 14 | medea
# Processing Record 7 of Set 14 | lengshuijiang
# Processing Record 8 of Set 14 | piacabucu
# Processing Record 9 of Set 14 | springdale
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | ishigaki
# Processing Record 12 of Set 14 | atchison
# Processing Record 13 of Set 14 | marshall
# Processing Record 14 of Set 14 | north platte
# Processing Record 15 of Set 14 | mezhevoy
# Processing Record 16 of Set 14 | malartic
# Processing Record 17 of Set 14 | newport
# Processing Record 18 of Set 14 | petrivka
# Processing Record 19 of Set 14 | kandalaksha
# Processing Record 20 of Set 14 | agadez
# Processing Record 21 of Set 14 | umm kaddadah
# Processing Record 22 of Set 14 | beroroha
# Processing Record 23 of Set 14 | adre
# Processing Record 24 of Set 14 | nakapiripirit
# Processing Record 25 of Set 14 | hami
# Processing Record 26 of Set 14 | castanos
# Processing Record 27 of Set 14 | santa fe
# Processing Record 28 of Set 14 | bogotol
# Processing Record 29 of Set 14 | luangwa
# Processing Record 30 of Set 14 | gravenhurst
# Processing Record 31 of Set 14 | tamiahua
# Processing Record 32 of Set 14 | neuquen
# Processing Record 33 of Set 14 | aquiraz
# Processing Record 34 of Set 14 | vao
# Processing Record 35 of Set 14 | kyra
# Processing Record 36 of Set 14 | manta
# Processing Record 37 of Set 14 | yozgat
# Processing Record 38 of Set 14 | burica
# City not found. Skipping...
# Processing Record 39 of Set 14 | popova
# Processing Record 40 of Set 14 | karasburg
# Processing Record 41 of Set 14 | yerbogachen
# Processing Record 42 of Set 14 | pierre
# Processing Record 43 of Set 14 | sadri
# Processing Record 44 of Set 14 | rosarito
# Processing Record 45 of Set 14 | cockburn town
# Processing Record 46 of Set 14 | lakhdenpokhya
# Processing Record 47 of Set 14 | haileybury
# Processing Record 48 of Set 14 | castellammare del golfo
# Processing Record 49 of Set 14 | codajas
# Processing Record 50 of Set 14 | sobinka
# Processing Record 1 of Set 15 | santa cruz
# Processing Record 2 of Set 15 | tombouctou
# Processing Record 3 of Set 15 | luganville
# Processing Record 4 of Set 15 | tual
# Processing Record 5 of Set 15 | panzhihua
# Processing Record 6 of Set 15 | dongying
# Processing Record 7 of Set 15 | rzhev
# Processing Record 8 of Set 15 | havoysund
# Processing Record 9 of Set 15 | sidney
# Processing Record 10 of Set 15 | maniitsoq
# Processing Record 11 of Set 15 | yuanli
# Processing Record 12 of Set 15 | oriximina
# Processing Record 13 of Set 15 | santa maria
# Processing Record 14 of Set 15 | nanakuli
# Processing Record 15 of Set 15 | inhambane
# Processing Record 16 of Set 15 | guaymas
# Processing Record 17 of Set 15 | straumen
# Processing Record 18 of Set 15 | quito
# Processing Record 19 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 20 of Set 15 | tigil
# Processing Record 21 of Set 15 | bulata
# Processing Record 22 of Set 15 | panlaitan
# Processing Record 23 of Set 15 | faya
# Processing Record 24 of Set 15 | butembo
# Processing Record 25 of Set 15 | paka
# Processing Record 26 of Set 15 | lata
# Processing Record 27 of Set 15 | kushmurun
# Processing Record 28 of Set 15 | naze
# Processing Record 29 of Set 15 | black river
# Processing Record 30 of Set 15 | aswan
# Processing Record 31 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 15 | santiago
# Processing Record 33 of Set 15 | witten
# Processing Record 34 of Set 15 | charleston
# Processing Record 35 of Set 15 | dingle
# Processing Record 36 of Set 15 | leh
# Processing Record 37 of Set 15 | zyryanka
# Processing Record 38 of Set 15 | isla vista
# Processing Record 39 of Set 15 | mvuma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[['City','Country', 'Lat', 'Lng', "Max Temp", "Humidity","Cloudiness","Wind Speed" ,"Current Description" ]]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kropotkin      RU  45.4375   40.5756     59.14        89          97
# 1          Bethel      US  41.3712  -73.4140     75.72        73          48
# 2    Punta Arenas      CL -53.1500  -70.9167     50.95        75         100
# 3       Jamestown      US  42.0970  -79.2353     75.18        61         100
# 4        Calabozo      VE   8.9242  -67.4293     85.82        67          99
# ..            ...     ...      ...       ...       ...       ...         ...
# 679        Dingle      PH  10.9995  122.6711     74.59        92          99
# 680           Leh      IN  34.1667   77.5833     56.48        55          68
# 681      Zyryanka      RU  65.7500  150.8500     28.60        61          43
# 682    Isla Vista      US  34.4133 -119.8610     99.07        61           0
# 683         Mvuma      ZW -19.2792   30.5283     72.05        24          14
#
#      Wind Speed Current Description
# 0          6.55     overcast clouds
# 1          7.94    scattered clouds
# 2         15.88     overcast clouds
# 3          5.99     overcast clouds
# 4          5.35     overcast clouds
# ..          ...                 ...
# 679        3.96     overcast clouds
# 680        5.14       broken clouds
# 681        3.42    scattered clouds
# 682        4.14           clear sky
# 683       17.52          few clouds
#
# [684 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
