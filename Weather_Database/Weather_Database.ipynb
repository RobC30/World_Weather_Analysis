# %%
# import dependencies

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c6a5c7b509fda8562fb78d6e53441ad

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | vila franca do campo
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | laguna
# Processing Record 5 of Set 1 | roma
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | taltal
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | maceio
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 1 | skovorodino
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | mwene-ditu
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | prescott
# Processing Record 27 of Set 1 | goundi
# Processing Record 28 of Set 1 | akyab
# Processing Record 29 of Set 1 | viedma
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | pacific grove
# Processing Record 33 of Set 1 | kesennuma
# City not found. Skipping...
# Processing Record 34 of Set 1 | akom
# Processing Record 35 of Set 1 | la ronge
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | marsh harbour
# Processing Record 38 of Set 1 | moerai
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | dalbeattie
# Processing Record 41 of Set 1 | buala
# Processing Record 42 of Set 1 | troitsko-pechorsk
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | srednekolymsk
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | grindavik
# Processing Record 48 of Set 1 | le port
# Processing Record 49 of Set 1 | agdam
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | pangody
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | bud
# Processing Record 5 of Set 2 | kahului
# Processing Record 6 of Set 2 | salinopolis
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | shenjiamen
# Processing Record 10 of Set 2 | kotma
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | kroya
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | dickinson
# Processing Record 16 of Set 2 | lasa
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | iwanai
# Processing Record 19 of Set 2 | martil
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | nang rong
# Processing Record 22 of Set 2 | awjilah
# Processing Record 23 of Set 2 | kovernino
# Processing Record 24 of Set 2 | whitley bay
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | nancha
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | mayor pablo lagerenza
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | marquette
# Processing Record 36 of Set 2 | rubiataba
# Processing Record 37 of Set 2 | rincon
# Processing Record 38 of Set 2 | honiara
# Processing Record 39 of Set 2 | egvekinot
# Processing Record 40 of Set 2 | praia da vitoria
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | pandan
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | pak phanang
# Processing Record 45 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | kozhevnikovo
# Processing Record 47 of Set 2 | whitehorse
# Processing Record 48 of Set 2 | siilinjarvi
# Processing Record 49 of Set 2 | menongue
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 3 | port-gentil
# Processing Record 3 of Set 3 | bela
# Processing Record 4 of Set 3 | shumikha
# Processing Record 5 of Set 3 | gat
# Processing Record 6 of Set 3 | homer
# Processing Record 7 of Set 3 | alvik
# Processing Record 8 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 3 | nioro
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | yerbogachen
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | odweyne
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | santa maria del oro
# Processing Record 17 of Set 3 | kokkola
# Processing Record 18 of Set 3 | naryan-mar
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | stornoway
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | kieta
# Processing Record 24 of Set 3 | kaeo
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | adre
# Processing Record 27 of Set 3 | djibo
# Processing Record 28 of Set 3 | manturovo
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 3 | rocha
# Processing Record 34 of Set 3 | spasskoye
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | wewak
# Processing Record 37 of Set 3 | preston
# Processing Record 38 of Set 3 | herat
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | jaisalmer
# Processing Record 41 of Set 3 | yumen
# Processing Record 42 of Set 3 | pangnirtung
# Processing Record 43 of Set 3 | port lincoln
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | hobyo
# Processing Record 46 of Set 3 | santa rosalia
# Processing Record 47 of Set 3 | hirara
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | aldama
# Processing Record 50 of Set 3 | dunmore east
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | bose
# Processing Record 4 of Set 4 | haines junction
# Processing Record 5 of Set 4 | sibolga
# Processing Record 6 of Set 4 | uchaly
# Processing Record 7 of Set 4 | dallas
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | puerto ayora
# Processing Record 10 of Set 4 | makhinjauri
# Processing Record 11 of Set 4 | trinidad
# Processing Record 12 of Set 4 | fevik
# Processing Record 13 of Set 4 | belyy yar
# Processing Record 14 of Set 4 | azul
# Processing Record 15 of Set 4 | goias
# Processing Record 16 of Set 4 | chiang khong
# Processing Record 17 of Set 4 | osoyoos
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | adrar
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | wembley
# Processing Record 22 of Set 4 | oum hadjer
# Processing Record 23 of Set 4 | kruisfontein
# Processing Record 24 of Set 4 | whyalla
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 4 | yamethin
# Processing Record 31 of Set 4 | virbalis
# Processing Record 32 of Set 4 | khilok
# Processing Record 33 of Set 4 | arlit
# Processing Record 34 of Set 4 | andenes
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | young
# Processing Record 38 of Set 4 | pokanayevka
# City not found. Skipping...
# Processing Record 39 of Set 4 | kavaratti
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | thatcham
# Processing Record 42 of Set 4 | port blair
# Processing Record 43 of Set 4 | san vicente
# Processing Record 44 of Set 4 | san policarpo
# Processing Record 45 of Set 4 | hualmay
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | killybegs
# Processing Record 49 of Set 4 | koubia
# Processing Record 50 of Set 4 | do gonbadan
# Processing Record 1 of Set 5 | labytnangi
# Processing Record 2 of Set 5 | witu
# Processing Record 3 of Set 5 | najran
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | hasaki
# Processing Record 7 of Set 5 | hobart
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | funadhoo
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | amapa
# Processing Record 13 of Set 5 | pisz
# Processing Record 14 of Set 5 | sur
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | bahia honda
# Processing Record 17 of Set 5 | kenora
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | nome
# Processing Record 20 of Set 5 | cockburn town
# Processing Record 21 of Set 5 | nantucket
# Processing Record 22 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 5 | kibre mengist
# Processing Record 24 of Set 5 | concord
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | vardo
# Processing Record 27 of Set 5 | gemena
# Processing Record 28 of Set 5 | moose factory
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | kabwe
# Processing Record 31 of Set 5 | charters towers
# Processing Record 32 of Set 5 | barrow
# Processing Record 33 of Set 5 | kaka
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | asau
# Processing Record 36 of Set 5 | hvide sande
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | margen
# Processing Record 39 of Set 5 | marienburg
# Processing Record 40 of Set 5 | katobu
# Processing Record 41 of Set 5 | mangrol
# Processing Record 42 of Set 5 | xinzhi
# Processing Record 43 of Set 5 | dunedin
# Processing Record 44 of Set 5 | shemonaikha
# Processing Record 45 of Set 5 | fare
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | carolina
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 6 | aljezur
# Processing Record 2 of Set 6 | mahajanga
# Processing Record 3 of Set 6 | raudeberg
# Processing Record 4 of Set 6 | maarianhamina
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | gondanglegi
# Processing Record 7 of Set 6 | areni
# Processing Record 8 of Set 6 | mahebourg
# Processing Record 9 of Set 6 | jamkhandi
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | ugoofaaru
# Processing Record 12 of Set 6 | port hawkesbury
# Processing Record 13 of Set 6 | tocantins
# Processing Record 14 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | riyadh
# Processing Record 17 of Set 6 | vanavara
# Processing Record 18 of Set 6 | broken hill
# Processing Record 19 of Set 6 | ponnani
# Processing Record 20 of Set 6 | aksha
# Processing Record 21 of Set 6 | port stanley
# Processing Record 22 of Set 6 | anjangaon
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | batticaloa
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | boguchany
# Processing Record 27 of Set 6 | lethem
# Processing Record 28 of Set 6 | polson
# Processing Record 29 of Set 6 | lakatoro
# Processing Record 30 of Set 6 | nikolskoye
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | camacha
# Processing Record 33 of Set 6 | matara
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | massaguet
# Processing Record 36 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 6 | hambantota
# Processing Record 38 of Set 6 | cururupu
# Processing Record 39 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | walvis bay
# Processing Record 42 of Set 6 | limon
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | half moon bay
# Processing Record 45 of Set 6 | abalak
# Processing Record 46 of Set 6 | araouane
# Processing Record 47 of Set 6 | naze
# Processing Record 48 of Set 6 | ostersund
# Processing Record 49 of Set 6 | sterling
# Processing Record 50 of Set 6 | fukue
# Processing Record 1 of Set 7 | fort myers beach
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | bowen
# Processing Record 4 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 7 | atamanskaya
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | antalaha
# Processing Record 8 of Set 7 | kudat
# Processing Record 9 of Set 7 | okhotsk
# Processing Record 10 of Set 7 | hyderabad
# Processing Record 11 of Set 7 | daugavpils
# Processing Record 12 of Set 7 | alihe
# Processing Record 13 of Set 7 | poum
# Processing Record 14 of Set 7 | maturin
# Processing Record 15 of Set 7 | san ramon
# Processing Record 16 of Set 7 | teahupoo
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 19 of Set 7 | gogrial
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | huarmey
# Processing Record 22 of Set 7 | robertsport
# Processing Record 23 of Set 7 | kingsport
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 7 | taree
# Processing Record 27 of Set 7 | ancud
# Processing Record 28 of Set 7 | pudozh
# Processing Record 29 of Set 7 | cajati
# Processing Record 30 of Set 7 | tautira
# Processing Record 31 of Set 7 | saint anthony
# Processing Record 32 of Set 7 | cherskiy
# Processing Record 33 of Set 7 | moa
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | lebedinyy
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | turukhansk
# Processing Record 39 of Set 7 | waingapu
# Processing Record 40 of Set 7 | muzhi
# Processing Record 41 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 7 | monterey
# Processing Record 43 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 7 | caborca
# Processing Record 46 of Set 7 | marechal candido rondon
# Processing Record 47 of Set 7 | kulhudhuffushi
# Processing Record 48 of Set 7 | ilulissat
# Processing Record 49 of Set 7 | skelleftea
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | kaz
# Processing Record 2 of Set 8 | saint-francois
# Processing Record 3 of Set 8 | bambanglipuro
# Processing Record 4 of Set 8 | chernyshevskiy
# Processing Record 5 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 8 | balma
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | bilma
# Processing Record 9 of Set 8 | lavrentiya
# Processing Record 10 of Set 8 | san cristobal
# Processing Record 11 of Set 8 | margate
# Processing Record 12 of Set 8 | shelburne
# Processing Record 13 of Set 8 | rehoboth
# Processing Record 14 of Set 8 | cabedelo
# Processing Record 15 of Set 8 | khandyga
# Processing Record 16 of Set 8 | ukiah
# Processing Record 17 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 8 | dicabisagan
# Processing Record 19 of Set 8 | mortka
# Processing Record 20 of Set 8 | nauta
# Processing Record 21 of Set 8 | camargo
# Processing Record 22 of Set 8 | ilo
# Processing Record 23 of Set 8 | bosaso
# Processing Record 24 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 8 | constitucion
# Processing Record 26 of Set 8 | eureka
# Processing Record 27 of Set 8 | urumqi
# Processing Record 28 of Set 8 | yenagoa
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | gillette
# Processing Record 31 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 8 | chernogorsk
# Processing Record 33 of Set 8 | kontagora
# Processing Record 34 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 35 of Set 8 | qobustan
# Processing Record 36 of Set 8 | soto la marina
# Processing Record 37 of Set 8 | russell
# Processing Record 38 of Set 8 | keti bandar
# Processing Record 39 of Set 8 | vao
# Processing Record 40 of Set 8 | columbus
# Processing Record 41 of Set 8 | tynda
# Processing Record 42 of Set 8 | bestobe
# Processing Record 43 of Set 8 | mayskiy
# Processing Record 44 of Set 8 | svetlogorsk
# Processing Record 45 of Set 8 | calatayud
# Processing Record 46 of Set 8 | otradnoye
# Processing Record 47 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 8 | itupiranga
# Processing Record 49 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 1 of Set 9 | gigmoto
# Processing Record 2 of Set 9 | solnechnyy
# Processing Record 3 of Set 9 | port hardy
# Processing Record 4 of Set 9 | seoul
# Processing Record 5 of Set 9 | westport
# Processing Record 6 of Set 9 | denpasar
# Processing Record 7 of Set 9 | yaan
# Processing Record 8 of Set 9 | ambanja
# Processing Record 9 of Set 9 | nara
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | amurzet
# Processing Record 13 of Set 9 | qasigiannguit
# Processing Record 14 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | carauari
# Processing Record 17 of Set 9 | kiama
# Processing Record 18 of Set 9 | puerto escondido
# Processing Record 19 of Set 9 | nizhniy tsasuchey
# Processing Record 20 of Set 9 | avera
# Processing Record 21 of Set 9 | sumenep
# Processing Record 22 of Set 9 | arica
# Processing Record 23 of Set 9 | tadine
# Processing Record 24 of Set 9 | baykit
# Processing Record 25 of Set 9 | xiongzhou
# Processing Record 26 of Set 9 | shubarshi
# Processing Record 27 of Set 9 | okato
# Processing Record 28 of Set 9 | jiayuguan
# Processing Record 29 of Set 9 | otane
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | dourbali
# Processing Record 32 of Set 9 | les cayes
# Processing Record 33 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 9 | tarakan
# Processing Record 35 of Set 9 | springdale
# Processing Record 36 of Set 9 | kirkwall
# Processing Record 37 of Set 9 | shimoda
# Processing Record 38 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 9 | puerto del rosario
# Processing Record 40 of Set 9 | harper
# Processing Record 41 of Set 9 | ecija
# Processing Record 42 of Set 9 | nuuk
# Processing Record 43 of Set 9 | marzuq
# Processing Record 44 of Set 9 | aqtobe
# Processing Record 45 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 9 | shirgaon
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | saint-denis
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | ransang
# Processing Record 1 of Set 10 | tiznit
# Processing Record 2 of Set 10 | huilong
# Processing Record 3 of Set 10 | lander
# Processing Record 4 of Set 10 | aykhal
# Processing Record 5 of Set 10 | chadiza
# Processing Record 6 of Set 10 | madimba
# Processing Record 7 of Set 10 | torbay
# Processing Record 8 of Set 10 | guerrero negro
# Processing Record 9 of Set 10 | opuwo
# Processing Record 10 of Set 10 | chernogolovka
# Processing Record 11 of Set 10 | salalah
# Processing Record 12 of Set 10 | general pico
# Processing Record 13 of Set 10 | miri
# Processing Record 14 of Set 10 | turkistan
# Processing Record 15 of Set 10 | goderich
# Processing Record 16 of Set 10 | college
# Processing Record 17 of Set 10 | chisinau
# Processing Record 18 of Set 10 | wawa
# Processing Record 19 of Set 10 | carutapera
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | birao
# Processing Record 22 of Set 10 | dhrangadhra
# Processing Record 23 of Set 10 | awbari
# Processing Record 24 of Set 10 | gizo
# Processing Record 25 of Set 10 | zemetchino
# Processing Record 26 of Set 10 | moyale
# Processing Record 27 of Set 10 | balkhash
# Processing Record 28 of Set 10 | galich
# Processing Record 29 of Set 10 | gobabis
# Processing Record 30 of Set 10 | calatrava
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | sept-iles
# Processing Record 33 of Set 10 | pahrump
# Processing Record 34 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 10 | pontes e lacerda
# Processing Record 36 of Set 10 | sandy bay
# Processing Record 37 of Set 10 | barra
# Processing Record 38 of Set 10 | san marcos
# Processing Record 39 of Set 10 | victoria
# Processing Record 40 of Set 10 | davila
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | gorontalo
# Processing Record 43 of Set 10 | cinco esquinas
# Processing Record 44 of Set 10 | poplar bluff
# Processing Record 45 of Set 10 | borogontsy
# Processing Record 46 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 47 of Set 10 | alexandria
# Processing Record 48 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 49 of Set 10 | zhigansk
# Processing Record 50 of Set 10 | pimenta bueno
# Processing Record 1 of Set 11 | agadez
# Processing Record 2 of Set 11 | sorland
# Processing Record 3 of Set 11 | magadan
# Processing Record 4 of Set 11 | qandala
# Processing Record 5 of Set 11 | mitsamiouli
# Processing Record 6 of Set 11 | kovdor
# Processing Record 7 of Set 11 | nemuro
# Processing Record 8 of Set 11 | saldanha
# Processing Record 9 of Set 11 | pulandian
# Processing Record 10 of Set 11 | emerald
# Processing Record 11 of Set 11 | can tho
# Processing Record 12 of Set 11 | kloulklubed
# Processing Record 13 of Set 11 | narsaq
# Processing Record 14 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 11 | pisco
# Processing Record 16 of Set 11 | namatanai
# Processing Record 17 of Set 11 | abu dhabi
# Processing Record 18 of Set 11 | baisha
# Processing Record 19 of Set 11 | vienna
# Processing Record 20 of Set 11 | victoria point
# Processing Record 21 of Set 11 | iskateley
# Processing Record 22 of Set 11 | patea
# Processing Record 23 of Set 11 | christchurch
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | stanghelle
# Processing Record 28 of Set 11 | bereda
# Processing Record 29 of Set 11 | ganzhou
# Processing Record 30 of Set 11 | tomatlan
# Processing Record 31 of Set 11 | warmbad
# Processing Record 32 of Set 11 | leningradskiy
# Processing Record 33 of Set 11 | san rafael
# Processing Record 34 of Set 11 | sovetskiy
# Processing Record 35 of Set 11 | berbera
# Processing Record 36 of Set 11 | kismayo
# Processing Record 37 of Set 11 | te anau
# Processing Record 38 of Set 11 | gueret
# Processing Record 39 of Set 11 | loandjili
# Processing Record 40 of Set 11 | ratnagiri
# Processing Record 41 of Set 11 | saint-augustin
# Processing Record 42 of Set 11 | jashpurnagar
# Processing Record 43 of Set 11 | kapiri mposhi
# Processing Record 44 of Set 11 | ermelo
# Processing Record 45 of Set 11 | nouadhibou
# Processing Record 46 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 47 of Set 11 | businga
# Processing Record 48 of Set 11 | sarankhola
# Processing Record 49 of Set 11 | yulara
# Processing Record 50 of Set 11 | karasburg
# Processing Record 1 of Set 12 | karaton
# Processing Record 2 of Set 12 | taksimo
# Processing Record 3 of Set 12 | itacoatiara
# Processing Record 4 of Set 12 | masuguru
# Processing Record 5 of Set 12 | guiratinga
# Processing Record 6 of Set 12 | burica
# City not found. Skipping...
# Processing Record 7 of Set 12 | kalabagh
# Processing Record 8 of Set 12 | moron
# Processing Record 9 of Set 12 | shamary
# Processing Record 10 of Set 12 | balabac
# Processing Record 11 of Set 12 | kailua
# Processing Record 12 of Set 12 | mersing
# Processing Record 13 of Set 12 | kurchanskaya
# Processing Record 14 of Set 12 | hovd
# Processing Record 15 of Set 12 | khetri
# Processing Record 16 of Set 12 | uzunovo
# Processing Record 17 of Set 12 | idrinskoye
# Processing Record 18 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 12 | mindelo
# Processing Record 20 of Set 12 | san miguelito
# Processing Record 21 of Set 12 | sinjar
# Processing Record 22 of Set 12 | tezu
# Processing Record 23 of Set 12 | medea
# Processing Record 24 of Set 12 | nelson bay
# Processing Record 25 of Set 12 | pingzhuang
# Processing Record 26 of Set 12 | sabha
# Processing Record 27 of Set 12 | ponta delgada
# Processing Record 28 of Set 12 | celestun
# Processing Record 29 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 12 | tooele
# Processing Record 31 of Set 12 | linqiong
# Processing Record 32 of Set 12 | alice springs
# Processing Record 33 of Set 12 | portland
# Processing Record 34 of Set 12 | sao jose da coroa grande
# Processing Record 35 of Set 12 | kalmunai
# Processing Record 36 of Set 12 | yarada
# Processing Record 37 of Set 12 | cap malheureux
# Processing Record 38 of Set 12 | berlevag
# Processing Record 39 of Set 12 | arkhipo-osipovka
# Processing Record 40 of Set 12 | meulaboh
# Processing Record 41 of Set 12 | chifeng
# Processing Record 42 of Set 12 | zyryanka
# Processing Record 43 of Set 12 | teguise
# Processing Record 44 of Set 12 | coahuayana
# Processing Record 45 of Set 12 | marsaxlokk
# Processing Record 46 of Set 12 | kushmurun
# Processing Record 47 of Set 12 | mathbaria
# Processing Record 48 of Set 12 | ecully
# Processing Record 49 of Set 12 | preeceville
# Processing Record 50 of Set 12 | nushki
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | camacupa
# Processing Record 3 of Set 13 | chardara
# Processing Record 4 of Set 13 | taoudenni
# Processing Record 5 of Set 13 | termiz
# Processing Record 6 of Set 13 | magadi
# Processing Record 7 of Set 13 | zalantun
# Processing Record 8 of Set 13 | khandbari
# Processing Record 9 of Set 13 | jacobabad
# Processing Record 10 of Set 13 | hohhot
# Processing Record 11 of Set 13 | ketchikan
# Processing Record 12 of Set 13 | vagur
# Processing Record 13 of Set 13 | klaksvik
# Processing Record 14 of Set 13 | los llanos de aridane
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | shingu
# Processing Record 17 of Set 13 | pimentel
# Processing Record 18 of Set 13 | den helder
# Processing Record 19 of Set 13 | altamira
# Processing Record 20 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 13 | salta
# Processing Record 22 of Set 13 | mantsala
# Processing Record 23 of Set 13 | lagoa
# Processing Record 24 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 13 | roseland
# Processing Record 26 of Set 13 | port hedland
# Processing Record 27 of Set 13 | sinop
# Processing Record 28 of Set 13 | karratha
# Processing Record 29 of Set 13 | pizhanka
# Processing Record 30 of Set 13 | ostrovnoy
# Processing Record 31 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 13 | patacamaya
# Processing Record 33 of Set 13 | cap-chat
# Processing Record 34 of Set 13 | honningsvag
# Processing Record 35 of Set 13 | witrivier
# City not found. Skipping...
# Processing Record 36 of Set 13 | aguimes
# Processing Record 37 of Set 13 | jining
# Processing Record 38 of Set 13 | lake charles
# Processing Record 39 of Set 13 | pitimbu
# Processing Record 40 of Set 13 | thinadhoo
# Processing Record 41 of Set 13 | mulege
# Processing Record 42 of Set 13 | ust-nera
# Processing Record 43 of Set 13 | madang
# Processing Record 44 of Set 13 | mago
# Processing Record 45 of Set 13 | bandiagara
# Processing Record 46 of Set 13 | matagami
# Processing Record 47 of Set 13 | hope
# Processing Record 48 of Set 13 | palotina
# Processing Record 49 of Set 13 | bonavista
# Processing Record 50 of Set 13 | japura
# Processing Record 1 of Set 14 | balkanabat
# Processing Record 2 of Set 14 | campechuela
# Processing Record 3 of Set 14 | lorengau
# Processing Record 4 of Set 14 | high level
# Processing Record 5 of Set 14 | los cordobas
# Processing Record 6 of Set 14 | erzin
# Processing Record 7 of Set 14 | clarence town
# Processing Record 8 of Set 14 | esmeralda
# Processing Record 9 of Set 14 | cayon
# Processing Record 10 of Set 14 | paracuru
# Processing Record 11 of Set 14 | uyemskiy
# Processing Record 12 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 14 | waitati
# Processing Record 14 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 14 | bilibino
# Processing Record 16 of Set 14 | conceicao da barra
# Processing Record 17 of Set 14 | kalaleh
# Processing Record 18 of Set 14 | skeldon
# Processing Record 19 of Set 14 | sao joao do paraiso
# Processing Record 20 of Set 14 | kabalo
# Processing Record 21 of Set 14 | sao miguel do araguaia
# Processing Record 22 of Set 14 | prince rupert
# Processing Record 23 of Set 14 | bac lieu
# Processing Record 24 of Set 14 | havre-saint-pierre
# Processing Record 25 of Set 14 | wukari
# Processing Record 26 of Set 14 | murzzuschlag
# Processing Record 27 of Set 14 | pravia
# Processing Record 28 of Set 14 | kilindoni
# Processing Record 29 of Set 14 | chandvad
# Processing Record 30 of Set 14 | el tigre
# Processing Record 31 of Set 14 | tarrafal
# Processing Record 32 of Set 14 | kedrovyy
# Processing Record 33 of Set 14 | bagdarin
# Processing Record 34 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 14 | souris
# Processing Record 37 of Set 14 | villablino
# Processing Record 38 of Set 14 | rawson
# Processing Record 39 of Set 14 | ahuimanu
# Processing Record 40 of Set 14 | lithgow
# Processing Record 41 of Set 14 | piacabucu
# Processing Record 42 of Set 14 | vestmannaeyjar
# Processing Record 43 of Set 14 | esmeraldas
# Processing Record 44 of Set 14 | bahia blanca
# Processing Record 45 of Set 14 | lumby
# Processing Record 46 of Set 14 | blagodarnyy
# Processing Record 47 of Set 14 | arvika
# Processing Record 48 of Set 14 | sroda wielkopolska
# Processing Record 49 of Set 14 | ozinki
# Processing Record 50 of Set 14 | beidao
# Processing Record 1 of Set 15 | rosario
# Processing Record 2 of Set 15 | alyangula
# Processing Record 3 of Set 15 | northam
# Processing Record 4 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 5 of Set 15 | funtua
# Processing Record 6 of Set 15 | kupang
# Processing Record 7 of Set 15 | liminangcong
# City not found. Skipping...
# Processing Record 8 of Set 15 | lensk
# Processing Record 9 of Set 15 | abu samrah
# Processing Record 10 of Set 15 | ambulu
# Processing Record 11 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 15 | vitim
# Processing Record 13 of Set 15 | burayevo
# Processing Record 14 of Set 15 | banjar
# Processing Record 15 of Set 15 | panorama
# Processing Record 16 of Set 15 | prince albert
# Processing Record 17 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 18 of Set 15 | itoman
# Processing Record 19 of Set 15 | palmer
# Processing Record 20 of Set 15 | kulachi
# Processing Record 21 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 15 | yeppoon
# Processing Record 23 of Set 15 | lakes entrance
# Processing Record 24 of Set 15 | teknaf
# Processing Record 25 of Set 15 | saint-joseph
# Processing Record 26 of Set 15 | arya
# Processing Record 27 of Set 15 | samut prakan
# Processing Record 28 of Set 15 | deep river
# Processing Record 29 of Set 15 | holme
# Processing Record 30 of Set 15 | anadyr
# Processing Record 31 of Set 15 | bull savanna
# Processing Record 32 of Set 15 | qui nhon
# Processing Record 33 of Set 15 | kununurra
# Processing Record 34 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 15 | bibiani
# Processing Record 36 of Set 15 | pangai
# Processing Record 37 of Set 15 | vestmanna
# Processing Record 38 of Set 15 | takhli
# Processing Record 39 of Set 15 | mildura
# Processing Record 40 of Set 15 | salinas
# Processing Record 41 of Set 15 | atar
# Processing Record 42 of Set 15 | south lyon
# Processing Record 43 of Set 15 | surt
# Processing Record 44 of Set 15 | koungheul
# Processing Record 45 of Set 15 | hearst
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[['City','Country', 'Lat', 'Lng', "Max Temp", "Humidity","Cloudiness","Wind Speed" ,"Current Description" ]]
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Atuona      PF  -9.8000 -139.0333     77.20        78
# 1    Vila Franca Do Campo      PT  37.7167  -25.4333     73.96        62
# 2               Cape Town      ZA -33.9258   18.4232     63.88        62
# 3                  Laguna      US  38.4210 -121.4238     75.09        61
# 4                    Roma      US  43.2128  -75.4557     70.95        67
# ..                    ...     ...      ...       ...       ...       ...
# 676                  Atar      MR  20.5169  -13.0499    103.05        14
# 677            South Lyon      US  42.4606  -83.6516     71.80        89
# 678                  Surt      LY  31.2089   16.5887     87.37        50
# 679             Koungheul      SN  13.9833  -14.8000     92.66        55
# 680                Hearst      CA  49.6835  -83.6665     46.45        95
#
#      Cloudiness  Wind Speed Current Description
# 0            18       20.87          light rain
# 1            26        8.43    scattered clouds
# 2             1        5.99           clear sky
# 3             0        1.01           clear sky
# 4            86        1.99     overcast clouds
# ..          ...         ...                 ...
# 676           5       12.44           clear sky
# 677          76        3.00       broken clouds
# 678           0       12.97           clear sky
# 679          56        8.84       broken clouds
# 680         100       11.92     overcast clouds
#
# [681 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
